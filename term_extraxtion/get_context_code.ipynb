# %%
import os
import re
from nltk.tokenize import TreebankWordTokenizer
import pandas as pd

from nltk.stem import WordNetLemmatizer

# %%
ready_df = pd.DataFrame()

# %%
def preprocess(text):

    tokenized_text = TreebankWordTokenizer().tokenize(text)
    
    wordsFiltered = []

    for w in tokenized_text:
        for wf in re.findall(r'(?u)(\w+)', w):
            #for wfreal in re.findall(r'(\D+)', wf):
            wordsFiltered.append(''.join(wf))
    
    return wordsFiltered

# %%
def get_context(file_path):
    
    with open(file_path) as fl:
        try:
            text = fl.read()
        except:
            print ("Error: " + file_path )
    
    reg_term = re.compile(r'&(.*?)!&')
    indexes = []
    for i in reg_term.finditer(text):
        indexes.append((i.start(), i.end()))

    left_context = []
    right_context = []
    left_word = []

    for ind in indexes:
        left_part = text[:ind[0]]
        right_part = text[ind[1]+1:]
        clear_left = preprocess(left_part)
        clear_right = preprocess(right_part)
    
    
        #left context
        if len(clear_left) > 5:
            left_context.append(clear_left[-5:])
            left_word.append(clear_left[-1])
        else:
            left_context.append(clear_left)
            if len(clear_left) > 0:
                left_word.append(clear_left[-1])
            else:
                left_word.append(' ')
    
        #right context
        if len(clear_right) > 5:
            right_context.append(clear_right[:5])
        else:
            right_context.append(clear_right)
            
    
    terms = reg_term.findall(text)
    
    global ready_df
    lemmatizer = WordNetLemmatizer()
    
    
    for i in range(len(terms)):
        lft = left_context[i]
        lw = str(left_word[i])
        term = terms[i]
        rgt = right_context[i]
        lc = ' '.join(lft)
        rc = ' '.join(rgt)
        
        df = pd.DataFrame([[lc, lw, term, rc]],
                      columns=['left_context', 'left_word', 'term', 'right_context'])
        ready_df = ready_df.append(df)

# %%
start_path = './terms_markup/Marked/'

for path, dirs, files in os.walk(start_path):

    for fname in files:
        if not fname.startswith('.'):
            get_context(start_path+fname)

# %%
from rutermextract import TermExtractor

def get_term_candidates(text):
    
    terms = []
    term_extractor = TermExtractor()

    for term in term_extractor(text):
        terms.append((term.normalized, term.count))

# %%
df_sorted = ready_df.sort_values(['left_word'])

# %%
df_sorted.head()
# Out:
#                     left_context left_word                           term  \
# 0                                                                  Маглев
# 0                                           Изменение возмущений в грунте
# 0                                                                  Облако
# 0  уроки соседа сверху каждые 10        10                        децибел
# 0     в нашей на расстоянии 1350      1350                   световых лет
#
#                        right_context
# 0   на тестовом запуске в префектуре
# 0  в зависимости от скорости снаряда
# 0    с точки зрения пользователя это
# 0   громкость звука становится в два
# 0        от Земли в созвездии Ориона

# %%
ready_df.to_csv('terms_context.csv', sep='\t')

# %%
df_sorted.to_csv('terms_sorted.tsv', sep = '\t')

# %%
lemma = WordNetLemmatizer()

# %%
import nltk
from nltk.tokenize import TreebankWordTokenizer
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
from nltk.tag import tnt
from nltk.corpus import treebank
from nltk.corpus.reader.conll import *

# %%
from pymystem3 import Mystem

m = Mystem()

# %%
unigrams = []
bigrams = []
trigrams = []
multigrams = []

lem_unigrams = []
lem_bigrams = []
lem_trigrams = []
lem_multigrams = []

for term in df_sorted['term']:
    if len(term.split()) == 1:
        unigrams.append(term.lower())
        lem_unigrams.append(m.lemmatize(term))
    elif len(term.split()) == 2:
        bigrams.append(term.lower())
        lem_bigrams.append(m.lemmatize(term))
    elif len(term.split()) == 3:
        trigrams.append(term.lower())
        lem_trigrams.append(m.lemmatize(term))
    else:
        multigrams.append(term.lower())
        lem_multigrams.append(m.lemmatize(term))

# %%
with open('rus_bigram.txt') as fl:
    bi = fl.read()
    
with open('rus_trigram.txt') as fl:
    tri = fl.read()
    
with open('rus_tetragram.txt') as fl:
    tetra = fl.read()

# %%
bi_freq = bi.split('\n')
tri_freq = tri.split('\n')
tetra_freq = tetra.split('\n')

# %%
def text_to_dict(list_of_ngrams):
        
    unique_ngrams = list(set(list_of_ngrams))

    numbers = []
    for item in unique_ngrams:
        word_num = list_of_ngrams.count(item)
        numbers.append(word_num)
    
    dictionary = dict(zip(unique_ngrams, numbers))
    
    return dictionary

# %%
def get_ngrams(list_of_words, n):
    ngrams = []
    for word in list_of_words:
        for i in range(len(word)-n+1):
            ngrams.append(word[i:i+n].lower())

    for n in ngrams:
        if '-' in n.split():
            ngrams.remove(n)
    
    n_dict = text_to_dict(ngrams)
    
    return n_dict

# %%
with open('add_terms.txt') as fl:
    wiki = fl.read()

# %%
wiki_terms = wiki.split('\n')

# %%
final_unigrams = []

for u in lem_unigrams:
    final_unigrams.append(u[0])

# %%
terms = final_unigrams + wiki_terms

# %%
flat_list = ' '.join(terms)

# %%
term_bi = get_ngrams(terms, 2)

# %%
from collections import Counter

top_bi = []
for i in range(300):
    top_bi.append(Counter(term_bi).most_common(300)[i][0])

# %%
unique_bi = []
for i in top_bi:
    if i not in bi_freq:
        unique_bi.append(i)

# %%
print(unique_bi)
# Out:
# ['фи', 'зи', 'нд', 'кс', 'ге', 'фо', 'фа', 'нг', 'нк', 'иф', 'рт', 'мп', 'ип', 'кц', 'пи', 'фр', 'эк', 'ев', 'аф', 'ба', 'еф', 'лл', 'рм', 'рф', 'уа', 'ум', 'кв', 'ук', 'и́', 'яц', 'рк', 'а́', 'ец', 'ау', 'фу', 'ке', 'фф', 'эм', 'мм', 'дж', 'пт', 'пп', 'мн', '́н', 'о́', 'нф', 'оч', 'эс', 'пс', 'нв', 'сц', 'рц', 'фл', 'гу', 'зе', 'е́', 'ца', 'эп', 'рв', 'хи', 'уи', 'уз', 'рп', '́т', 'кн', 'эл', 'рд', 'хр', 'йр', 'сф', 'пц', 'оо', 'эн', 'рб', 'йк', 'тк', '́р', 'еа', 'яр', 'кк', 'гм', 'уц', 'хе', 'ье', 'ха', 'см', 'вт', 'эр', 'юз', 'ао', 'мк', 'юм', 'йд', 'оэ', '́я', 'эг', 'co', 'кз', 'гг', 'йт', '́м', 'тт', '́з']

# %%
term_tri = get_ngrams(terms, 3)

top_tri = []
for i in range(300):
    top_tri.append(Counter(term_tri).most_common(300)[i][0])

# %%
print(top_tri)
# Out:
# ['ция', 'аци', 'ный', 'ова', 'ост', 'ров', 'изм', 'иро', 'нос', 'сть', 'ват', 'ент', 'ать', 'льн', 'али', 'аль', 'оло', 'ика', 'тер', 'лиз', 'иза', 'тал', 'лог', 'про', 'тро', 'ант', 'кон', 'тор', 'ьны', 'сти', 'нци', 'ати', 'гия', 'ист', 'оги', 'стр', 'нти', 'ато', 'кат', 'тив', 'они', 'ата', 'енц', 'ари', 'ивн', 'тич', 'ест', 'тра', 'ком', 'сте', 'ици', 'кци', 'вар', 'ори', 'ван', 'ден', 'ано', 'нан', 'мет', 'ген', 'рац', 'ери', 'инг', 'ома', 'ина', 'акт', 'тик', 'ани', 'дис', 'еск', 'рен', 'ект', 'ром', 'ман', 'вер', 'ифи', 'ние', 'нтн', 'ива', 'ичн', 'вны', 'ера', 'роп', 'ени', 'три', 'пре', 'ото', 'ите', 'аст', 'рин', 'окс', 'иде', 'иал', 'ник', 'оти', 'зат', 'ски', 'иче', 'мен', 'тет', 'чес', 'пер', 'мат', 'био', 'ном', 'ион', 'ети', 'ези', 'зац', 'мин', 'иац', 'ста', 'ств', 'анс', 'род', 'тац', 'ета', 'оме', 'ита', 'пар', 'рив', 'цио', 'нац', 'кти', 'кац', 'рок', 'риз', 'ере', 'тиз', 'яци', 'ран', 'ляц', 'тво', 'ьно', 'диа', 'онд', 'иль', 'мия', 'фор', 'кий', 'экс', 'инт', 'сси', 'рны', 'тен', 'оми', 'цир', 'изи', 'зия', 'кол', 'фар', 'фил', 'тин', 'рия', 'она', 'гра', 'оби', 'нте', 'или', 'еди', 'етр', 'тно', 'нтр', 'тны', 'ами', 'ния', 'анд', 'гле', 'топ', 'ана', 'кси', 'нес', 'ерс', 'оно', 'нде', 'рон', 'дро', 'рат', 'сия', 'фик', 'мон', 'лин', 'омб', 'ико', 'оли', 'зон', 'аро', 'ане', 'нны', 'риа', 'нта', 'офи', 'рма', 'лек', 'пли', 'бан', 'мед', 'уля', 'кса', 'мби', 'офо', 'ино', 'дер', 'фер', 'вен', 'оге', 'фра', 'рал', 'онс', 'тар', 'зио', 'нал', 'омп', 'циа', 'бин', 'спе', 'саб', 'чно', 'есс', 'арт', 'опл', 'иол', 'онт', 'вол', 'ете', 'син', 'рес', 'пат', 'низ', 'енн', 'ити', 'рет', 'еро', 'рак', 'инк', 'сен', 'аба', 'тир', 'лит', 'уал', 'нит', 'рот', 'рез', 'уль', 'иот', 'нси', 'бер', 'енд', 'нда', 'тиц', 'кри', 'ате', 'чны', 'ини', 'фак', 'опо', 'тез', 'иво', 'лер', 'рси', 'кул', 'ель', 'пле', 'бия', 'фиц', 'пек', 'арф', 'ими', 'нет', 'рте', 'рит', 'раф', 'ене', 'лен', 'льт', 'кре', 'цен', 'пор', 'фоб', 'оте', 'тру', 'ема', 'иск', 'сам', 'ктр', 'ерк', 'пол', 'рфа', 'лей', 'ура', 'мац', 'лир', 'кот', 'еми', 'дже', 'либ', 'еци', 'тан', 'тиф', 'дин']

# %%
print(tri_freq)
# Out:
# ['рав', 'ств', 'пра', 'ени', 'ать', 'ове', 'ани', 'лов', 'сво', 'ело', 'чел', 'ост', 'ого', 'ния', 'ста', 'ест', 'век', 'аво', 'ажд', 'ние', 'льн', 'име', 'ова', 'при', 'каж', 'обо', 'или', 'жды', 'тат', 'воб', 'дый', 'бод', 'аци', 'его', 'еет', 'тья', 'мее', 'лен', 'тва', 'ных', 'енн', 'тво', 'аль', 'ван', 'сто', 'ьно', 'про', 'ног', 'ако', 'нов', 'сти', 'бра', 'пол', 'олж', 'дол', 'все', 'раз', 'ным', 'тор', 'нос', 'жен', 'ред', 'общ', 'ель', 'тел', 'оди', 'чес', 'как', 'сно', 'тве', 'има', 'пре', 'щес', 'ним', 'вле', 'нны', 'тьс', 'нно', 'шен', 'ься', 'аст', 'осу', 'быт', 'сов', 'ыть', 'осн', 'одн', 'лжн', 'нию', 'ран', 'бще', 'что', 'ват', 'оль', 'чен', 'сту', 'иче', 'рес', 'ном', 'ден', 'ежд', 'нац', 'вер', 'оже', 'рин', 'вен', 'туп', 'род', 'зов', 'нар', 'стр', 'обр', 'еоб', 'дос', 'есп', 'она', 'ото', 'ьны', 'лич', 'нии', 'тоя', 'аро', 'бес', 'гос', 'кот', 'суд', 'жно', 'ное', 'ава', 'под', 'печ', 'нст', 'уда', 'дно', 'ной', 'авн', 'ече', 'ход', 'нен', 'ции', 'уще', 'ате', 'льс', 'оро', 'для', 'еск', 'мож', 'ами', 'вов', 'ово', 'ели', 'олн', 'оду', 'жде', 'дст', 'обе', 'кон', 'вно', 'дру', 'азо', 'так', 'соц', 'еди', 'вны', 'ека', 'дей', 'циа', 'тра', 'оци', 'пос', 'дов', 'ите', 'сть', 'изн', 'нал', 'ейс', 'дин', 'ьст', 'ког', 'тер', 'кой', 'сре', 'сем', 'арс', 'зак', 'спе', 'защ', 'воз', 'ний', 'йст', 'ащи', 'имо', 'нич', 'ион', 'ере', 'рга', 'тся', 'ман', 'ник', 'рст', 'едс', 'ыми', 'уча', 'нас', 'овн', 'жет', 'ара', 'оде', 'гра', 'дек', 'ичн', 'дар', 'ров', 'щит', 'иал', 'убе', 'вля', 'раб', 'жду', 'ини', 'кла', 'беж', 'рац', 'аве', 'гат', 'лар', 'екл', 'сущ', 'икт', 'спр', 'чно', 'ско', 'ина', 'огр', 'зна', 'слу', 'руг', 'иту', 'ави', 'вам', 'вол', 'рак', 'кто', 'вое', 'ира', 'вни', 'люд', 'люч', 'рат', 'орг', 'тре', 'меж', 'авл', 'иск', 'овл', 'ить', 'нео', 'сод', 'сео', 'рем', 'пле', 'клю', 'вит', 'гла', 'ано', 'ную', 'иги', 'ити', 'упл', 'ерш', 'инс', 'рас', 'тру', 'лиг', 'оящ', 'луч', 'без', 'рел', 'мая', 'ром', 'щег', 'дим', 'цио', 'рои', 'вою', 'яни', 'аже', 'анн', 'ций', 'ерж', 'нак', 'лас', 'дер', 'або', 'обх', 'ода', 'ибо', 'либ', 'едо', 'ому', '']

# %%
unique_tri = []
for i in top_tri:
    if i not in tri_freq:
        unique_tri.append(i)

# %%
print(unique_tri)
# Out:
# ['ция', 'ный', 'изм', 'иро', 'ент', 'али', 'оло', 'ика', 'лиз', 'иза', 'тал', 'лог', 'тро', 'ант', 'нци', 'ати', 'гия', 'ист', 'оги', 'нти', 'ато', 'кат', 'тив', 'они', 'ата', 'енц', 'ари', 'ивн', 'тич', 'ком', 'сте', 'ици', 'кци', 'вар', 'ори', 'нан', 'мет', 'ген', 'ери', 'инг', 'ома', 'акт', 'тик', 'дис', 'рен', 'ект', 'ифи', 'нтн', 'ива', 'ера', 'роп', 'три', 'окс', 'иде', 'оти', 'зат', 'ски', 'мен', 'тет', 'пер', 'мат', 'био', 'ети', 'ези', 'зац', 'мин', 'иац', 'анс', 'тац', 'ета', 'оме', 'ита', 'пар', 'рив', 'кти', 'кац', 'рок', 'риз', 'тиз', 'яци', 'ляц', 'диа', 'онд', 'иль', 'мия', 'фор', 'кий', 'экс', 'инт', 'сси', 'рны', 'тен', 'оми', 'цир', 'изи', 'зия', 'кол', 'фар', 'фил', 'тин', 'рия', 'оби', 'нте', 'етр', 'тно', 'нтр', 'тны', 'анд', 'гле', 'топ', 'ана', 'кси', 'нес', 'ерс', 'оно', 'нде', 'рон', 'дро', 'сия', 'фик', 'мон', 'лин', 'омб', 'ико', 'оли', 'зон', 'ане', 'риа', 'нта', 'офи', 'рма', 'лек', 'пли', 'бан', 'мед', 'уля', 'кса', 'мби', 'офо', 'ино', 'фер', 'оге', 'фра', 'рал', 'онс', 'тар', 'зио', 'омп', 'бин', 'саб', 'есс', 'арт', 'опл', 'иол', 'онт', 'ете', 'син', 'пат', 'низ', 'рет', 'еро', 'инк', 'сен', 'аба', 'тир', 'лит', 'уал', 'нит', 'рот', 'рез', 'уль', 'иот', 'нси', 'бер', 'енд', 'нда', 'тиц', 'кри', 'чны', 'фак', 'опо', 'тез', 'иво', 'лер', 'рси', 'кул', 'бия', 'фиц', 'пек', 'арф', 'ими', 'нет', 'рте', 'рит', 'раф', 'ене', 'льт', 'кре', 'цен', 'пор', 'фоб', 'оте', 'ема', 'сам', 'ктр', 'ерк', 'рфа', 'лей', 'ура', 'мац', 'лир', 'еми', 'дже', 'еци', 'тан', 'тиф']

# %%
term_4 = get_ngrams(terms, 4)

top_4 = []
for i in range(300):
    top_4.append(Counter(term_4).most_common(300)[i][0])

# %%
unique_4 = []
for i in top_4:
    if i not in tetra_freq:
        unique_4.append(i)

# %%
print(unique_4)
# Out:
# ['ация', 'иров', 'рова', 'ализ', 'олог', 'ьный', 'логи', 'енци', 'огия', 'лиза', 'атор', 'ката', 'кция', 'вный', 'ивны', 'тали', 'атал', 'тивн', 'изат', 'нция', 'зато', 'иаци', 'нано', 'таци', 'тика', 'ески', 'яция', 'ляци', 'каци', 'ский', 'рный', 'циро', 'тичн', 'дент', 'тный', 'анти', 'ентн', 'енти', 'нный', 'рокс', 'ризм', 'диац', 'ьнос', 'тери', 'рива', 'ерен', 'тром', 'меди', 'икац', 'тиче', 'арок', 'асти', 'исти', 'тнос', 'нтно', 'иоло', 'окса', 'лизм', 'комп', 'чнос', 'есте', 'ромб', 'нест', 'едиа', 'иден', 'варо', 'анес', 'ильн', 'итет', 'тези', 'ивар', 'троп', 'саба', 'тизм', 'ицир', 'чный', 'фика', 'зонд', 'ифик', 'метр', 'атив', 'нтро', 'абан', 'ксаб', 'мент', 'стез', 'тиро', 'мета', 'нтич', 'арфа', 'варф', 'ичны', 'фари', 'рфар', 'отоп', 'маци', 'арин', 'ропо', 'оген', 'оман', 'фици', 'итац', 'стиц', 'инте', 'рати', 'конс', 'офил', 'лект', 'спек', 'пара', 'низм', 'коти', 'ктив', 'атер', 'ндер', 'омби', 'топл', 'икот', 'стру', 'факт', 'мбин', 'трац', 'нтны', 'угле', 'фоби', 'отин', 'ектр', 'омет', 'нико', 'обия', 'нтер', 'рист', 'опли', 'лиро', 'пози', 'тифи', 'екци', 'онде', 'кома', 'рени', 'ериа', 'ранс', 'аном', 'амин', 'ента', 'сивн', 'омат', 'прот', 'ифиц', 'риал', 'антр', 'стик', 'форм', 'ктро', 'ерац', 'мате', 'дерк', 'екти', 'арте', 'граф', 'анда', 'рком', 'ливо', 'фрак', 'ерко', 'ракт', 'нциа', 'манд', 'офоб', 'плив', 'биот', 'иото', 'ейро', 'тенц', 'диск', 'ника', 'мати', 'аноч', 'енит', 'ариз', 'внос', 'зиол', 'леро', 'мони', 'коло', 'фере', 'част', 'ерси', 'очас', 'окси', 'ефак', 'ноча', 'тефа', 'пект', 'ртеф', 'ниро', 'тиль', 'дина', 'дисп', 'омия', 'ивно', 'глер', 'ренц', 'орма', 'ибер', 'ибри', 'инац', 'нейр', 'конт', 'проп', 'есси', 'тица', 'верс', 'розо', 'нкци', 'исте', 'ерод', 'уляц', 'морф', 'ория', 'ните', 'укци', 'езия', 'уаль', 'иста', 'ония', 'адже', 'езио', 'номи', 'стер', 'ндро', 'казу', 'пция', 'биом', 'рнос', 'линг', 'зиро', 'цесс', 'зный', 'опия', 'фили', 'атия', 'ноло', 'гадж', 'вере', 'либе', 'изир', 'таль', 'ониз', 'фила', 'ерал', 'етиз', 'сиро', 'арны', 'дифф', 'сизм', 'джет', 'етер', 'увер', 'воло', 'рали', 'акта', 'етри', 'бера', 'суве', 'элек', 'экст', 'итив', 'иони', 'конв', 'ункц', 'тари']

# %%
fl = open('tetragrams.txt', 'w')
for t in unique_4:
    fl.write(t + '\n')

fl.close()

# %%
fl = open('trigrams.txt', 'w')
for t in unique_tri:
    fl.write(t + '\n')

fl.close()

# %%
fl = open('bigrams.txt', 'w')
for t in unique_bi:
    fl.write(t + '\n')

fl.close()

# %%
df = pd.read_csv('./Freq2011/freqrnc2011.csv', sep='\t')
freq_dict = df[['Lemma','Freq(ipm)']]
sorted_freq = freq_dict.sort_values(by=['Freq(ipm)'])

# %%
lemmas = list(freq_dict['Lemma'])
values = list(freq_dict['Freq(ipm)'])

dictionary = dict(zip(lemmas, values))

# %%
freq_range = []

for term in terms:
    freq_range.append(dictionary.get(term))

# %%
freq_range = [x for x in freq_range if x != None]

# %%
print(freq_range)
# Out:
# [43.0, 0.59999999999999998, 0.5, 0.80000000000000004, 8.3000000000000007, 0.40000000000000002, 119.59999999999999, 0.5, 8.3000000000000007, 3.7999999999999998, 8.4000000000000004, 1.8999999999999999, 5.7000000000000002, 26.800000000000001, 4.0999999999999996, 1.7, 28.399999999999999, 14.300000000000001, 0.5, 8.3000000000000007, 6.2000000000000002, 2.1000000000000001, 6.2000000000000002, 0.5, 14.300000000000001, 7.7000000000000002, 1.0, 0.80000000000000004, 2.7000000000000002, 19.399999999999999, 0.69999999999999996, 1.5, 5.2000000000000002, 43.0, 5.7000000000000002, 57.5, 20.300000000000001, 1.7, 69.299999999999997, 1.1000000000000001, 1.1000000000000001, 6.2000000000000002, 0.80000000000000004, 0.40000000000000002, 2.2999999999999998, 37.100000000000001, 0.40000000000000002, 8.3000000000000007, 0.69999999999999996, 8.3000000000000007, 8.3000000000000007, 0.69999999999999996, 3.2999999999999998, 0.59999999999999998, 3.5, 3.7999999999999998, 10.4, 8.3000000000000007, 0.40000000000000002, 1.8999999999999999, 1.8999999999999999, 1.3, 0.69999999999999996, 35.399999999999999, 24.699999999999999, 2.8999999999999999, 3.7000000000000002, 1.2, 0.59999999999999998, 20.300000000000001, 119.59999999999999, 2.3999999999999999, 2.7000000000000002, 8.3000000000000007, 1.0, 8.8000000000000007, 2.0, 6.5999999999999996, 1.8, 1.8, 1.5, 0.80000000000000004, 4.0, 0.40000000000000002, 1.1000000000000001, 1.1000000000000001, 0.90000000000000002, 2.5, 64.400000000000006, 11.199999999999999, 2.2999999999999998, 1.2, 8.8000000000000007, 0.69999999999999996, 23.199999999999999, 1151.3, 0.80000000000000004, 8.3000000000000007, 4.5, 8.3000000000000007, 1.1000000000000001, 3.1000000000000001, 2.5, 8.8000000000000007, 7.4000000000000004, 35.799999999999997, 0.90000000000000002, 3.5, 8.5999999999999996, 0.40000000000000002, 0.40000000000000002, 7.9000000000000004, 6.2000000000000002, 2.8999999999999999, 1.1000000000000001, 1.6000000000000001, 6.7999999999999998, 1.5, 0.5, 1.0, 1.0, 0.5, 5.9000000000000004, 0.5, 0.59999999999999998, 8.5, 2.8999999999999999, 1.0, 69.299999999999997, 1.8, 3.5, 1.5, 0.69999999999999996, 3.5, 8.5999999999999996, 23.199999999999999, 23.199999999999999, 25.699999999999999, 7.4000000000000004, 0.40000000000000002, 0.40000000000000002, 3.3999999999999999, 8.3000000000000007, 6.2000000000000002, 0.40000000000000002, 1.7, 0.80000000000000004, 0.90000000000000002, 0.69999999999999996, 0.59999999999999998, 1.3, 7.9000000000000004, 0.40000000000000002, 3.7000000000000002, 4.2999999999999998, 8.3000000000000007, 0.59999999999999998, 2.2000000000000002, 20.300000000000001, 0.90000000000000002, 1.7, 1.7, 4.4000000000000004, 8.3000000000000007, 4.7000000000000002, 4.0999999999999996, 1.8999999999999999, 4.7000000000000002, 0.59999999999999998, 0.69999999999999996, 0.5, 1.8999999999999999, 4.7000000000000002, 4.7000000000000002, 8.5999999999999996, 2.7000000000000002, 0.40000000000000002, 0.59999999999999998, 8.8000000000000007, 0.40000000000000002, 3.5, 2.8999999999999999, 2.1000000000000001, 8.4000000000000004, 2.3999999999999999, 3.7000000000000002, 0.90000000000000002, 11.199999999999999, 3.1000000000000001, 11.800000000000001, 4.7000000000000002, 1.7, 59.399999999999999, 0.40000000000000002, 7.7000000000000002, 0.5, 0.40000000000000002, 4.2999999999999998, 0.40000000000000002, 0.5, 1.2, 7.9000000000000004, 3.1000000000000001, 7.9000000000000004, 7.9000000000000004, 5.2000000000000002, 4.2000000000000002, 4.2000000000000002, 0.40000000000000002, 5.2000000000000002, 0.40000000000000002, 0.69999999999999996, 69.299999999999997, 1.5, 4.0999999999999996, 1.8999999999999999, 0.69999999999999996, 1.7, 2.7000000000000002, 6.5999999999999996, 0.5, 119.59999999999999, 14.300000000000001, 0.69999999999999996, 0.40000000000000002, 0.40000000000000002, 0.59999999999999998, 0.5, 4.0999999999999996, 4.7000000000000002, 8.3000000000000007, 1.2, 3.7999999999999998, 1.1000000000000001, 20.300000000000001, 8.3000000000000007, 8.5999999999999996, 31.89999999 ...

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("russian")

l=[stemmer.stem(word) for word in terms]

# %%
suffixes3 = []
suffixes4 = []
prefixes3 = []
prefixes4 = []

for morph in l:
    suffixes3.append(morph[-3:])
    suffixes4.append(morph[-4:])
    prefixes3.append(morph[:3])
    prefixes4.append(morph[:4])

# %%
suf3 = list(set(suffixes3) - set(tri_freq))

# %%
suf4 = list(set(suffixes4) - set(tetra_freq))

# %%
pref3 = list(set(prefixes3) - set(tri_freq))

# %%
pref4 = list(set(prefixes4) - set(tetra_freq))

# %%
print(suf3)
# Out:
# ['бан', 'лиз', 'лир', 'ечк', 'ета', 'бат', 'чик', 'сис', 'хул', 'прэ', 'лит', 'мик', 'арн', 'гез', 'ерз', 'ье́', 'арш', 'зол', 'теч', 'чек', 'фем', 'юзл', 'етр', 'ушк', 'пат', 'дра', 'туц', 'акц', 'гон', 'емн', 'риа', 'мин', 'ант', 'атн', 'оэп', 'орм', 'роп', 'си́', 'ндр', '-кв', 'нер', 'опе', 'нир', 'лак', 'пор', 'вра', 'бэк', 'арг', 'азн', 'ера', 'иац', 'айс', 'апс', 'тим', 'о́з', 'инг', 'аме', 'рбц', 'омн', 'тет', 'топ', 'арк', 'онг', 'зус', 'нез', 'нтн', 'ноф', 'куц', 'урн', 'пир', 'и́т', 'бин', 'ибр', 'амп', 'онк', 'ктр', 'отн', 'фоб', 'лев', 'пац', 'иум', 'ing', 'ill', 'таф', 'итн', 'тен', 'мот', 'ю́д', 'упп', 'епт', 'шиз', 'ри́', 'алл', 'над', 'кем', 'ига', 'абр', 'орп', 'льф', 'тес', 'инд', 'аор', 'лот', 'нсц', 'нкт', 'вац', 'тип', 'иат', 'ект', 'роб', 'фин', 'зюм', 'ерс', 'озн', 'аск', 'гиу', 'нет', 'уум', 'зи́', 'еоф', 'ажн', 'сH4', 'маз', 'инч', 'уац', 'люз', 'лет', 'тур', 'емм', 'SLS', 'мрт', 'сн4', 'амк', 'нат', 'iO2', 'а́л', 'лус', 'сан', 'нгв', 'ерк', 'азм', 'oop', 'пук', 'роф', 'якр', 'зиц', 'поз', 'оид', 'зер', 'ту', 'опн', 'и́ц', 'наз', 'урт', 'рит', 'рта', 'боц', 'гер', 'CO', 'ипц', 'фиц', 'рум', 'тез', 'екс', 'ерн', 'тул', 'DoS', 'зон', 'рез', 'аук', 'тус', 'лех', '́дн', 'э́г', 'янс', 'ующ', 'идж', 'мон', 'нон', 'анц', 'дев', 'раф', 'гам', 'еян', 'имн', 'ерц', 'P', 'иор', 'оре', 'ерм', 'спл', 'бел', 'дор', 'анг', 'вин', 'бут', 'лац', 'ьер', 'сив', 'лив', 'кев', 'сик', '́мн', 'NH4', 'тек', 'мок', 'исс', 'сус', '́нс', 'енс', 'ийн', 'руз', 'бек', 'ожк', 'янт', 'рен', 'мус', 'бац', 'нкц', 'урс', 'пад', 'идн', 'фил', 'еин', 'IP', 'иар', 'укц', 'цин', 'дон', 'нул', 'айн', 'ивн', 'пек', 'там', 'зис', 'днк', 'а́н', 'кер', 'овк', 'ерг', '́нт', 'ть,', 'а́с', 'том', 'тиш', 'рап', 'гог', 'а́т', 'е́т', 'коз', 'зот', 'бск', 'епц', 'éрк', 'бул', 'ноб', 'ива', '́зм', 'ерт', 'онт', 'агм', 'роц', 'бфр', 'кур', 'итр', 'зоф', 'аба', 'аит', 'акт', 'онс', 'кол', 'лат', 'дом', 'орн', 'бад', 'ург', 'изм', 'иом', 'тин', 'езн', 'фаз', 'сид', 'ома', 'енц', 'мбр', 'тар', 'е́р', 'ауз', 'дац', 'тюр', 'ржк', 'поц', 'орц', 'ия,', 'кац', 'игм', 'рфн', 'ниц', 'нам', 'фон', 'соб', 'рим', 'унд', 'ляц', 'CH4', 'мец', 'вут', 'пут', 'рик', 'лин', 'хоз', 'очн', 'кат', 'рон', 'но', 'тон', 'амм', 'осф', 'окн', 'со', 'юмп', 'снк', 'стк', 'упн', 'таб', 'скн', 'бок', 'фуз', 'и́м', 'етк', 'ерв', 'гор', '́тн', 'фос', 'ваз', 'мев', 'ляр', 'нкл', 'лим', 'CO2', 'кел', 'гид', 'икц', 'елл', 'гет', 'ьтн', 'ент', 'льт', 'итч', 'орт', 'дел', 'вил', 'а́ц', 'фен', 'о́б', 'а́ф', 'дум', 'рмн', 'енд', 'н2', 'о́н', 'фор', 'мен', 'рет', 'кта', 'зац', 'опс', 'DTV', 'кст', 'фаг', 'ятк', 'ви́', 'боз', 'иде', 'тр,', 'мац', 'омб', 'онд', '2O5', 'ти́', 'есс', 'таж', 'риг', 'етн', 'ист', 'еющ', 'DNS', 'лал', 'фол', 'тив', 'одж', 'анд', 'тик', 'мпц', 'одч', 'коп', 'игн', 'о́т', 'тиц', 'ноз', 'убл', 'гин', 'асс', 'вок', 'анс', 'шет', 'пог', 'онз', 'еяд', 'мер', 'ица', 'хим', 'вар', 'мол', 'тум', 'таз', 'тац', 'екц', '6N6', 'рив', 'K2', 'аз,', 'ген', 'рид', 'сор', 'орф', 'гал', 'точ', 'т', 'ярн', 'лог', 'раж', 'анш', 'кор', 'бус', 'х', 'кум', 'зик', 'кул', 'зиф', 'гац']

# %%
fl = open('suf3.txt', 'w')
for s in suf3:
    if len(s) == 3:
        fl.write(s + '\n')
fl.close()

# %%
fl = open('suf4.txt', 'w')
for s in suf4:
    if len(s) == 4:
        fl.write(s + '\n')
fl.close()

# %%
fl = open('pref3.txt', 'w')
for s in pref3:
    if len(s) == 3:
        fl.write(s + '\n')
fl.close()

# %%
fl = open('pref4.txt', 'w')
for s in pref4:
    if len(s) == 4:
        fl.write(s + '\n')
fl.close()
