# %%
import pandas as pd
import re
import os

# %%
classes = pd.read_csv('scipop_allfeat.csv', encoding = 'utf-8')

# %%
from __future__ import (absolute_import, division,
                        print_function, unicode_literals)
# отключим предупреждения Anaconda
import warnings
warnings.simplefilter('ignore')

# будем отображать графики прямо в jupyter'e
# %pylab inline

#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 8, 5
import pandas as pd
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly
import plotly.graph_objs as go

# %%
classes['category'].value_counts()
# Out:
# 1    187
# 2    160
# 3    138
# Name: category, dtype: int64

# %%
classes['category'].value_counts().plot(kind='bar', label='category')
plt.legend()
plt.title('Распределение текстов по сложности');

# %%
classes.shape
# Out:
# (485, 30)

# %%
classes = classes.drop(['Unnamed: 0.1'], axis = 1)

# %%
classes.to_csv('scipop_allfeat.csv', encoding = 'utf-8')

# %%
classes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485 entries, 0 to 484
# Data columns (total 29 columns):
# Unnamed: 0               485 non-null int64
# text                     485 non-null object
# category                 485 non-null int64
# sentences                485 non-null int64
# words                    485 non-null int64
# chars                    485 non-null int64
# syllabs                  485 non-null int64
# diff words               485 non-null int64
# avg word lenght          485 non-null float64
# avg sentence lenght      485 non-null float64
# avg sent length-chars    485 non-null float64
# avg syllabs in word      485 non-null float64
# avg syllabs in sent      485 non-null float64
# diff words persent       485 non-null float64
# FRE                      485 non-null float64
# FKG                      485 non-null float64
# SMOG                     485 non-null float64
# CLI                      485 non-null float64
# ...

# %%
features = list(set(classes.columns) - set(['category']))

classes[features].hist(figsize=(20,12));

# %%
sns.pairplot(classes[features + ['category']], hue='category');
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
_, axes = plt.subplots(1,2, sharey=True, figsize=(16,6))

sns.boxplot(x='category', y='FRE', data=classes, ax=axes[0]);

# %%
_, axes = plt.subplots(1,2, sharey=True, figsize=(16,6))

sns.boxplot(x='category', y='CLI', data=classes, ax=axes[0]); #no

# %%
_, axes = plt.subplots(1,2, sharey=True, figsize=(16,6))
sns.boxplot(x='category', y='DCH', data=classes, ax=axes[0]);#no

# %%
_, axes = plt.subplots(1,2, sharey=True, figsize=(16,6))
sns.boxplot(x='category', y='FKG', data=classes, ax=axes[0]); #no

# %%
_, axes = plt.subplots(1,2, sharey=True, figsize=(16,6))
sns.boxplot(x='category', y='FRE', data=classes, ax=axes[0]);

# %%
_, axes = plt.subplots(1,2, sharey=True, figsize=(16,6))
sns.boxplot(x='category', y='GF', data=classes, ax=axes[0]); #no

# %%
_, axes = plt.subplots(1,2, sharey=True, figsize=(16,6))
sns.boxplot(x='category', y='adjs', data=classes, ax=axes[0]);

# %%
_, axes = plt.subplots(1,2, sharey=True, figsize=(16,6))
sns.boxplot(x='category', y='nouns', data=classes, ax=axes[0]);

# %%
_, axes = plt.subplots(1,2, sharey=True, figsize=(16,6))
sns.boxplot(x='category', y='verbs', data=classes, ax=axes[0]); #no

# %%
_, axes = plt.subplots(1,2, sharey=True, figsize=(16,6))
sns.boxplot(x='category', y='conjs', data=classes, ax=axes[0]);

# %%
_, axes = plt.subplots(1,2, sharey=True, figsize=(16,6))
sns.boxplot(x='category', y='prepositions', data=classes, ax=axes[0]); #no

# %%
_, axes = plt.subplots(1,2, sharey=True, figsize=(16,6))
sns.boxplot(x='category', y='words', data=classes, ax=axes[0]);

# %%
_, axes = plt.subplots(1,2, sharey=True, figsize=(16,6))
sns.boxplot(x='category', y='rude words', data=classes, ax=axes[0]);

# %%
_, axes = plt.subplots(1,2, sharey=True, figsize=(16,6))
sns.boxplot(x='category', y='common words', data=classes, ax=axes[0]);

# %%
_, axes = plt.subplots(1,2, sharey=True, figsize=(16,6))
sns.boxplot(x='category', y='talk words', data=classes, ax=axes[0]);

# %%
_, axes = plt.subplots(1,2, sharey=True, figsize=(16,6))
sns.boxplot(x='category', y='measures', data=classes, ax=axes[0]);

# %%
_, axes = plt.subplots(1,2, sharey=True, figsize=(16,6))
sns.boxplot(x='category', y='sentences', data=classes, ax=axes[0]);

# %%
_, axes = plt.subplots(1,2, sharey=True, figsize=(16,6))
sns.boxplot(x='category', y='syllabs', data=classes, ax=axes[0]);

# %%
_, axes = plt.subplots(1,2, sharey=True, figsize=(16,6))
sns.boxplot(x='category', y='diff words persent', data=classes, ax=axes[0]);

# %%
_, axes = plt.subplots(1,2, sharey=True, figsize=(16,6))
sns.boxplot(x='category', y='diff words', data=classes, ax=axes[0]); #no

# %%
_, axes = plt.subplots(1,2, sharey=True, figsize=(16,6))
sns.boxplot(x='category', y='avg syllabs in sent', data=classes, ax=axes[0]);

# %%
_, axes = plt.subplots(1,2, sharey=True, figsize=(16,6))
sns.boxplot(x='category', y='avg syllabs in word', data=classes, ax=axes[0]);

# %%
_, axes = plt.subplots(1,2, sharey=True, figsize=(16,6))
sns.boxplot(x='category', y='avg word lenght', data=classes, ax=axes[0]);

# %%
_, axes = plt.subplots(1,2, sharey=True, figsize=(16,6))
sns.boxplot(x='category', y='chars', data=classes, ax=axes[0]);

# %%
_, axes = plt.subplots(1,2, sharey=True, figsize=(16,6))
sns.boxplot(x='category', y='avg sentence lenght', data=classes, ax=axes[0]); #no

# %%
_, axes = plt.subplots(1,2, sharey=True, figsize=(16,6))
sns.boxplot(x='category', y='avg sent length-chars', data=classes, ax=axes[0]);
