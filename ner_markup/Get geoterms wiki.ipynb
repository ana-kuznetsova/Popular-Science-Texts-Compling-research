# %%
import re
import urllib.request
import bs4 as bs
import pandas as pd
import os

# %%
from requests_html import HTMLSession
session = HTMLSession()
import time
import string

# %%
source = session.get('http://wikilivres.ru/%D0%A1%D0%BB%D0%BE%D0%B2%D0%B0%D1%80%D1%8C_%D0%B3%D0%B5%D0%BE%D0%B3%D1%80%D0%B0%D1%84%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B8%D1%85_%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D0%B9')

# %%
geo_links = source.html.absolute_links

# %%
geo_pages = get_pages(geo_links) ;
# Out:
#   0%|          | 0/79 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-174-fa642ad11ceb> in <module>()
# ----> 1 geo_pages = get_pages(geo_links) ;
#
# <ipython-input-171-372b60a3900d> in get_pages(links)
#       4         page = session.get(link)
#       5         pages.append(page)
# ----> 6         time.sleep(5)
#       7     return pages
#       8
#
# KeyboardInterrupt:

# %%
def get_pages(links):
    pages = []
    for link in tqdm(links):
        page = session.get(link)
        pages.append(page)
        time.sleep(5)
    return pages

def isEnglish(s):
    try:
        s.encode(encoding='utf-8').decode('ascii')
    except UnicodeDecodeError:
        return False
    else:
        return True

def get_geo_names(pages):
    geo_names = []
    for page in tqdm(pages):
        found = page.html.find('a') 
        for element in found:
            try:
                title = element.attrs['title']
                if title.startswith('w:'):
                    if not isEnglish(title[2:]):
                        geo_names.append(title[2:])
            except KeyError:
                continue
    return geo_names

# %%
geo_names = get_geo_names(geo_pages)
# Out:
#   0%|          | 0/79 [00:00<?, ?it/s]
#  41%|████      | 32/79 [00:00<00:00, 315.70it/s]
#  91%|█████████ | 72/79 [00:00<00:00, 354.50it/s]
# 100%|██████████| 79/79 [00:00<00:00, 346.82it/s]

# %%
geo_names = list(set(geo_names))

# %%
geo_df = pd.DataFrame({'location': geo_names})
geo_df
# Out:
#                           location
# 0                          Испания
# 1                              США
# 2                   Большой Лондон
# 3                         Танзания
# 4                           Рединг
# 5                         Норвегия
# 6                       Камберленд
# 7                           Фарсал
# 8                          Бад-Эмс
# 9                            Орхус
# 10                  Великобритания
# 11                          Юкатан
# 12                      Черногория
# 13                         Шеффилд
# 14                          Кувейт
# 15                          Греция
# 16                        Брэдфорд
# 17                       Волгоград
# 18                          Африка
# 19                   острова Чагос
# 20                           Нигер
# 21                           Девон
# 22                        Бразилия
# 23                         Даугава
# 24                       Сэндхарст
# 25           Ляодунский полуостров
# 26                      Айзенштадт
# 27                     Хердфордшир
# 28                          Абадан
# 29      Арабская Республика Египет
# ..                             ...
# 614                       Бристоль
# 615                    Нортгемптон
# 616             Кингстон-апон-Халл
# 617                         Сербия
# 618                       Молдавия
# 619                        Ватикан
# 620                         Килдэр
# 621                        Гренада
# 622       Доминиканская Республика
# 623                         де-юре
# 624                         Лондон
# 625                          Булак
# 626                           Чили
# 627                          Эйвон
# 628  Объединенные Арабские Эмираты
# 629                       Мидлсбро
# 630                      Фельдкирх
# 631                      Филиппины
# 632                     Бедфордшир
# 633                      Уссурийск
# 634              Фарерские Острова
# 635                          Непал
# 636                          Самоа
# 637              Коморские Острова
# 638                           Линц
# 639                         Усмань
# 640                         Египет
# 641                        Гонконг
# 642                       Кембридж
# 643    Южно-Африканская Республика
#
# [644 rows x 1 columns]
