# %%
import re
import os
from tqdm import tqdm_notebook

# %%
def slurp(path):
    try:
        with open(path, 'r') as fo:
            text = fo.read()
    except UnicodeDecodeError:
        print(path)
        with open(path, 'r', encoding='cp1252') as fo:
            text = fo.read()
    return text

def spit(texts, file_names):
    for text, file_name in tqdm_notebook(zip(texts, file_names)):
        with open(file_name, 'w') as fo:
            fo.write(text)

def read_dir(input_path):
    texts = []
    files = []
    print('Reading files...')
    for root, dirs, filenames in os.walk(input_path):
        files.extend(filenames)
        for filename in tqdm_notebook(filenames):
            file_path = os.path.join(root, filename)
            if '.ipynb' not in file_path:
                text = slurp(file_path)
                texts.append(text)
    print('Number of texts: ', len(texts))
    return texts, files

def preprocess(input_path, output_path):
    texts, filenames = read_dir(input_path)
    pattern = re.compile(r'[А-ЯЁа-яё\.\-\d]+')
    preprocessed = []
    print('Preprocessing files...')
    for text in tqdm(texts):
        preproc_text = ' '.join(re.findall(pattern, text))
        preprocessed.append(preproc_text)
    paths = [output_path + name for name in filenames if 'ipynb' not in name]
    print('Number of texts: ', len(texts))
    print('Number of paths:', len(paths))
    print('Writing to files...')
    spit(preprocessed, paths)
    print('All done, Buddy!')

# %% [markdown]
# ## Preprocess texts before parsing

# %%
spit_dir = '/home/nst/mount/data/linguistics_hse/popular-science-research/Tomita_Parser/tomita-parser/build/bin/sci_corpus/'
slurp_dir = '/home/nst/mount/data/share/yd/popular_science_texts_store_copy'

# %%
chrdk = preprocess(slurp_dir, spit_dir)
# Out:
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
#   0%|          | 0/707 [00:00<?, ?it/s]
# Reading files...
#   1%|          | 6/707 [00:00<00:12, 54.75it/s]
#   2%|▏         | 14/707 [00:00<00:11, 61.65it/s]
#   3%|▎         | 20/707 [00:00<00:11, 59.24it/s]
#   4%|▍         | 29/707 [00:00<00:10, 65.30it/s]
#   5%|▌         | 38/707 [00:00<00:10, 64.70it/s]
#   7%|▋         | 47/707 [00:00<00:09, 68.41it/s]
#   8%|▊         | 57/707 [00:00<00:09, 71.64it/s]
#   9%|▉         | 65/707 [00:00<00:08, 72.38it/s]
#  10%|█         | 73/707 [00:01<00:08, 72.22it/s]
#  11%|█▏        | 81/707 [00:01<00:08, 71.68it/s]
#  13%|█▎        | 90/707 [00:01<00:08, 73.06it/s]
#  14%|█▍        | 98/707 [00:01<00:08, 72.23it/s]
#  15%|█▌        | 108/707 [00:01<00:08, 74.06it/s]
#  17%|█▋        | 117/707 [00:01<00:07, 74.23it/s]Exception in thread Thread-131:
# Traceback (most recent call last):
#   File "/home/nst/anaconda3/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/home/nst/anaconda3/lib/python3.6/site-packages/tqdm/_tqdm.py", line 144, in run
#     for instance in self.tqdm_cls._instances:
#   File "/home/nst/anaconda3/lib/python3.6/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
#
# 100%|██████████| 707/707 [00:09<00:00, 73.75it/s]
# 100%|██████████| 1500/1500 [00:29<00:00, 50.77it/s]
# 100%|██████████| 5166/5166 [00:58<00:00, 87.77it/s]
# 0it [00:00, ?it/s]
# 100%|██████████| 1454/1454 [00:15<00:00, 96.60it/s]
# 0it [00:00, ?it/s]
# 100%|██████████| 600/600 [00:13<00:00, 44.99it/s]
# 100%|██████████| 1/1 [00:00<00:00, 5005.14it/s]
# 100%|██████████| 542/542 [00:11<00:00, 46.72it/s]
# 100%|██████████| 1/1 [00:00<00:00, 5629.94it/s]
# 100%|██████████| 11171/11171 [03:56<00:00, 47.17it/s]
# 100%|██████████| 1/1 [00:00<00:00, 2452.81it/s]
# 0it [00:00, ?it/s]
# 100%|██████████| 1413/1413 [00:20<00:00, 70.23it/s]
# 100%|██████████| 1/1 [00:00<00:00, 6765.01it/s]
# 100%|██████████| 3850/3850 [00:58<00:00, 65.50it/s]
# 0it [00:00, ?it/s]
# 100%|██████████| 562/562 [00:09<00:00, 60.12it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.60it/s]
# 100%|██████████| 499/499 [00:12<00:00, 41.10it/s]
# 100%|██████████| 499/499 [00:14<00:00, 33.85it/s]
# 100%|██████████| 500/500 [00:10<00:00, 49.37it/s]
# 100%|██████████| 500/500 [00:07<00:00, 67.47it/s]
# 100%|██████████| 500/500 [00:05<00:00, 99.52it/s]
# 100%|██████████| 500/500 [00:07<00:00, 66.54it/s]
# 100%|██████████| 500/500 [00:12<00:00, 39.50it/s]
# 100%|██████████| 500/500 [00:08<00:00, 58.74it/s]
# 100%|██████████| 89/89 [00:01<00:00, 76.92it/s]
#   0%|          | 67/31052 [00:00<00:46, 668.37it/s]
# Number of texts:  31052
# Preprocessing files...
# 100%|██████████| 31052/31052 [00:13<00:00, 2247.23it/s]
# 0it [00:00, ?it/s]
# Number of texts:  31052
# Number of paths: 31052
# Writing to files...
# 31052it [06:37, 78.14it/s]
# All done, Buddy!

# %% [markdown]
# ## Launch on test sample

# %%
test_input = '/home/nst/data/api_nis/ner_data/final_markup/'

# %%
marked = []
for root, dirs, filenames in os.walk(test_input):
    for filename in tqdm_notebook(filenames):
        path = test_input + filename
        text = slurp(path)
        marked.append(text)
marked = list(set(marked))
# Out:
# HBox(children=(IntProgress(value=0, max=175), HTML(value='')))

# %% [markdown]
# ### Find names in marked text

# %%
pattern = re.compile(r'\&[А-ЯЁа-яё\-\s]+!\&')
names_list = []
for text in marked:
    names = re.findall(pattern, text)
    clean_names = [name.replace('&', '').replace('!', '') for name in names]
    names_list.extend(clean_names)

# %%
to_pop = [51, 52, 54, 123 , 131, 151, 157, 185, 196, 381, 398, 461, 511, 600, 655, 664, 929,
          982, 1210, 1236, 1261, 1334, 1340, 1401, 1408, 1503, 1511, 1527, 1582, 1638, 1656,
         1670, 1704, 1706]
for i in to_pop:
    names_list.pop(i)

# %%
names_list[0]
# Out:
# 'Леонардо да Винчи'

# %%
with open('evaluation_names.txt', 'w') as fo:
    for name in names_list:
        fo.write(name+'\n')

# %% [markdown]
# ## Test sample texts

# %%
marked_texts, file_names = read_dir(test_input)
texts = [text.replace('&', '').replace('!', '') for text in marked_texts]
# Out:
# Reading files...
# HBox(children=(IntProgress(value=0, max=175), HTML(value='')))
# Number of texts:  175

# %%
test_output = '/home/nst/data/api_nis/ner_data/texts_eval/'

# %%
pattern = re.compile(r'[А-ЯЁа-яё\.\-\d]+')
preprocessed = []
print('Preprocessing files...')
for text in tqdm_notebook(texts):
    preproc_text = ' '.join(re.findall(pattern, text))
    preprocessed.append(preproc_text)
paths = [test_output + name for name in file_names]
print('Number of texts: ', len(texts))
print('Number of paths:', len(paths))
print('Writing to files...')
spit(preprocessed, paths)
print('All done, Buddy!')
# Out:
# Preprocessing files...
# HBox(children=(IntProgress(value=0, max=175), HTML(value='')))
# Number of texts:  175
# Number of paths: 175
# Writing to files...
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# All done, Buddy!

# %%
import pandas as pd

# %%
meta_table = pd.read_csv('/home/alapidus/NIS/articles_with_meta.tsv', sep='\t')

# %%
len(meta_table)
# Out:
# 30628

# %%
rem_dup_meta = meta_table.drop_duplicates(subset='path', keep='first')
len(rem_dup_meta)
# Out:
# 30628

# %%
for row in meta_table.iterrows():
    if 'Гоффман' in row[1].text:
        text = row[1].text.split()
        try:
            name_index = text.index('Гоффман')
            left = name_index - 3
            right = name_index +4 
            context = ' '.join(text[left:right])
            print('Title:', row[1].title)
            print('Context:', context)
            #print(row[1].path)
        except ValueError:
            continue
# Out:
# Title: Множественные «я»
# Context: чем вытеснение. Но Гоффман находит способ показать,
# Title: Поведение в публичных местах
# Context: с большим трудом. Гоффман — автор, которого
# Title: Социальное &laquo;лицо&raquo;
# Context: еврейско-русского происхождения Эрвинг Гоффман был первым из
# Title: Социальные роли
# Context: то, что Эрвинг Гоффман называл ролевой дистанцией,
# Title: Представление себя другим в теории Гоффмана
# Context: по крайней мере. Гоффман был первым, кто
# Title: Стратегические интеракции
# Context: это тот, который Гоффман называет наивным. Это
# Title: Понятие фрейма у Гоффмана
# Context: имеет весьма косвенное. Гоффман пишет о фреймах,
# Title: Социология эмоций
# Context: некоторые не одобряются. Гоффман написал несколько статей
# Title: Понятие стигмы у Гоффмана
# Context:
# Title: Теория фреймов
# Context: что позднее Ирвинг Гоффман назовет "транспонированием" -
# Title: Классовый статус: сигналы и символы
# Context: этими заданиями. Но Гоффман пошел дальше, чем

# %% [markdown]
# # NER-PARSER

# %%
import bs4 as bs

# %%
output = slurp('/home/nst/data/api_nis/ner_module/tomita-parser/build/bin/names.xml')

# %%
def parse_by_document(output):
    xml = bs.BeautifulSoup(output, 'lxml')
    documents = xml.find_all('document')
    print('Number of documents:', len(documents))
    filenames = []
    num_names = []
    names_final = []
    for doc in tqdm_notebook(documents):
        names_found = doc.find_all('name')
        names = [name.get('val').title() for name in names_found]
        names = delete_common_words(names)
        names = delete_geo_terms(names)
        if names:
            #print(names)
            num_names.append(len(names))
            names_final.append('|'.join(names))
            filename = doc.attrs['url'][1:]
            filenames.append(filename)
    df = pd.DataFrame({'file':filenames,
                      'NEnum': num_names,
                      'NE': names_final})
    print('Finished!')
    return df

# %%
ner_df = parse_by_document(output)
# Out:
# Number of documents: 155
# HBox(children=(IntProgress(value=0, max=155), HTML(value='')))
# Finished!

# %%
with open('/home/nst/data/api_nis/ner_module/other_dir/full_names_list.txt', 'r') as fo:
    corpora_names = fo.readlines()

# %%
def count_words(text):
    text = str(text.values)
    return len(text.split())
def sub_win_slash(strings):
    return [s.replace('\\', '/') if 'postnauka' in s else s for s in strings]

# %%
def extract_meta(ner_df, meta_df):
    filenames = ner_df.file
    names_mentioned = ner_df.NE
    ne_nums = ner_df.NEnum
    paths = sub_win_slash(meta_df.path)
    genres = []
    rubrics = []
    num_words = []
    number_nes = []
    fnames = []
    final_mentions = []
    for fname, num, men in tqdm(zip(filenames, ne_nums, names_mentioned)):
        for path in paths:
            if '/'+fname in path:
                if 'postnauka' in path:
                    path = path.replace('/', '\\')
                    row = meta_df.loc[meta_df['path'] == path]
                    genres.append(''.join(row.genre.values))
                    rubrics.append(''.join(row.final_rubrics.values))
                    num_words.append(count_words(row.text))
                    number_nes.append(num)
                    fnames.append(fname)
                    final_mentions.append(men)
                else:
                    row = meta_df.loc[meta_df['path'] == path]
                    genres.append(''.join(row.genre.values))
                    rubrics.append(''.join(row.final_rubrics.values))
                    num_words.append(count_words(row.text))
                    number_nes.append(num)
                    fnames.append(fname)
                    final_mentions.append(men)
                    
    df = pd.DataFrame({'genre':genres,
                      'rubric': rubrics,
                      'num_words': num_words,
                      'NE_num': number_nes,
                      'file': fnames,
                      'NE': final_mentions})
    print('Finished!')
    return df

# %%
ner_meta = extract_meta(ner_df, meta_table)
# Out:
# 2665it [00:25, 105.44it/s]
# Finished!

# %%
ner_meta = ner_meta.loc[ner_meta['genre'] != '']

# %%
len(ner_meta)
# Out:
# 2664

# %%
set(ner_meta.genre)
# Out:
# {'FAQ', 'Блоги', 'Лекции'}

# %%
ner_meta = ner_meta.replace('FAQ', 'Блоги')

# %%
len(ner_meta[ner_meta.rubric == 'Экономика'])
# Out:
# 91

# %%
ner_meta = ner_meta.drop_duplicates(subset='file', keep='first')
len(ner_meta)
# Out:
# 2665

# %%
ner_meta.to_csv('/home/alapidus/NIS/ner_data/ner_count.tsv', sep = '\t')

# %%
set(ner_meta.rubric)
# Out:
# {'Computer Science',
#  'Биология',
#  'История',
#  'Космос',
#  'Культура',
#  'Математика',
#  'Мусор',
#  'Науки о земле',
#  'Политология',
#  'Психология',
#  'Социология',
#  'Технологии',
#  'Физика',
#  'Физиология человека',
#  'Философия',
#  'Футурология',
#  'Химия',
#  'Экономика',
#  'Язык'}

# %% [markdown]
# ## Rank per rubric

# %%
def rank_per_rubric(ner_meta_df, rubric):
    rubrics_df = ner_meta_df[ner_meta_df.rubric == rubric]
    full_names_list = []
    for row in rubrics_df.iterrows():
        names = row[1].NE
        full_names_list.extend(names.split('|'))
    names_dict = dict(Counter(full_names_list))
    names_sorted = sorted(names_dict.items(), key = lambda x:x[1], reverse=True)
    names = [name[0] for name in names_sorted]
    mentions = [name[1] for name in names_sorted]
    names_sorted_df = pd.DataFrame({'name':names,
                                'mentions': mentions})
    print('Rubric:', rubric)
    return names_sorted_df

# %%
cs_rank = rank_per_rubric(ner_meta, 'Computer Science')
cs_rank.to_csv('/home/alapidus/NIS/ner_data/cs_ranking.tsv', sep='\t')
cs_rank
# Out:
# Rubric: Computer Science
#      mentions                         name
# 0           5                       Шеннон
# 1           5                     Чистяков
# 2           4                  Ник Бостром
# 3           4                     Курцвейл
# 4           3                      Тьюринг
# 5           3                      Цермело
# 6           2                      Хэмминг
# 7           2                Сергей Марков
# 8           2                      Миронов
# 9           2                       Сергей
# 10          2                         Пайк
# 11          1               Джером Писенти
# 12          1      Курцвейла Сингулярность
# 13          1                  Ханс Бергер
# 14          1                       Бергер
# 15          1                Уильям Добелл
# 16          1                      Добелла
# 17          1              Руслан Пермяков
# 18          1               Суперкомпьютер
# 19          1                   Брисколини
# 20          1                Акихисы Иноуэ
# 21          1                        Томас
# 22          1                  Колмогорова
# 23          1                      Шеннона
# 24          1                      Шэннона
# 25          1               М. Б. Малютова
# 26          1                      Гюйгенс
# 27          1                        Пауль
# 28          1            Семенович Пинскер
# 29          1                   Левенштейн
# ..        ...                          ...
# 96          1                       Брукса
# 97          1                      Декстер
# 98          1                          Мэй
# 99          1                    Стив Голд
# 100         1                         Голд
# 101         1               Артем Фаермарк
# 102         1                   Рахманинов
# 103         1               Гарриета Грина
# 104         1               Мичио Сакамото
# 105         1                Аксела Грэлла
# 106         1                  Алекс Грэлл
# 107         1                Тиэко Асакава
# 108         1                      Асакава
# 109         1               Уильям Баклэнд
# 110         1              Зигмунда Фрейда
# 111         1  Человек-Киборг Кевин Уорвик
# 112         1   Вернер Теодор Отто Форсман
# 113         1                      Форсман
# 114         1                        Стэпп
# 115         1                         Яном
# 116         1                 Томас Миджли
# 117         1                   Розенблатт
# 118         1                 Джеффри Пайк
# 119         1                    Чистякова
# 120         1            Николай Иосафович
# 121         1                        Попов
# 122         1                      Маркони
# 123         1              Яндекса Тихонов
# 124         1     Робот-Журналист Сяо Нань
# 125         1                 Стивен Руссо
#
# [126 rows x 2 columns]

# %%
bio_rank = rank_per_rubric(ner_meta, 'Биология')
bio_rank
# Out:
# Rubric: Биология
#      mentions                        name
# 0           9                      Дарвин
# 1           4                     Дарвина
# 2           4                     Холдейн
# 3           4                    Тимонова
# 4           4               Синъя Яманака
# 5           4                 Патрик Хаус
# 6           4                      Теркер
# 7           3               Чарльз Дарвин
# 8           3                       Часто
# 9           3                     Флеминг
# 10          3                 Ратгерского
# 11          3                     Кингдон
# 12          3                     Брайант
# 13          2           Сколтеха Гельфанд
# 14          2                 Дженни Клэк
# 15          2                  Роберт Кох
# 16          2                      Кто-То
# 17          2               Популяционная
# 18          2                      Бурцев
# 19          2             Чарльза Дарвина
# 20          2       Сколтеха Петр Сергиев
# 21          2                     Цетлина
# 22          2         Моисеевича Бонгарда
# 23          2                      Вентер
# 24          2                    Гарварда
# 25          2                     Жерихин
# 26          2          Татьяна Строганова
# 27          2                        Вэбб
# 28          2                   Северинов
# 29          2                      Беркли
# ..        ...                         ...
# 453         1                      Гексли
# 454         1                      Броуди
# 455         1                       Эрлих
# 456         1                      Рейвен
# 457         1                    Фаррелла
# 458         1                    Меландер
# 459         1                Пауль Мюллер
# 460         1           Муравьи-Листорезы
# 461         1                     Мюллера
# 462         1                       Янцен
# 463         1                  Вернадский
# 464         1           Адольфа Зейлахера
# 465         1                 Томаса Горо
# 466         1                      Норрел
# 467         1                 Джек Хорнер
# 468         1             Юджина Штермера
# 469         1               Роберт Пломин
# 470         1               Поведенческая
# 471         1            Сергея Ижевского
# 472         1              Павла Певзнера
# 473         1                     Омского
# 474         1                    Томского
# 475         1              Гронингенского
# 476         1  Сколтеха Филиппа Хайтовича
# 477         1               Бенджамин Мур
# 478         1                     Опарина
# 479         1                  Садерланду
# 480         1               Метью Поунеру
# 481         1                       Карла
# 482         1                 Фенга Жанга
#
# [483 rows x 2 columns]

# %%
hist_rank = rank_per_rubric(ner_meta, 'История')
hist_rank
# Out:
# Rubric: История
#       mentions            name
# 0           16          Сталин
# 1           12            Петр
# 2            9         Галилей
# 3            8         Сталина
# 4            7          Кто-То
# 5            7         Фукидид
# 6            6      Аристотель
# 7            6    Артем Ефимов
# 8            6           Ленин
# 9            6    Данилевского
# 10           5         Геродот
# 11           5          Энрике
# 12           5           Гоббс
# 13           5              Ви
# 14           4      Гумбольдта
# 15           4       Гумбольдт
# 16           4            Карл
# 17           4  Артема Ефимова
# 18           4           Часто
# 19           4        Фукидида
# 20           4            Пьер
# 21           4         Умберто
# 22           3         Омского
# 23           3         Шекспир
# 24           3      Керенского
# 25           3       Ксенофонт
# 26           3          Ельцин
# 27           3          Плиний
# 28           3     Португальцы
# 29           3          Струве
# ...        ...             ...
# 1020         1           Г. И.
# 1021         1           Русью
# 1022         1         Ковалев
# 1023         1         Харальд
# 1024         1       Керенский
# 1025         1       Чойбалсан
# 1026         1     Н. Т. Самет
# 1027         1         Яковлев
# 1028         1           Четко
# 1029         1       Пономарев
# 1030         1  Игоря Сутягина
# 1031         1         Сталину
# 1032         1           Чикко
# 1033         1      Диоклетиан
# 1034         1        Кузнецов
# 1035         1      Солженицын
# 1036         1        Иеронима
# 1037         1    Сталинградом
# 1038         1         Эриксон
# 1039         1   Стивен Коткин
# 1040         1         Лазарев
# 1041         1  Филиппа Арьеса
# 1042         1   Жака Ле Гоффа
# 1043         1   Ле Руа Ладюри
# 1044         1    Франсуа Фюре
# 1045         1       Теофраста
# 1046         1    Малиновского
# 1047         1   Железногорска
# 1048         1          Бергер
# 1049         1          Аврора
#
# [1050 rows x 2 columns]

# %%
cos_rank = rank_per_rubric(ner_meta, 'Космос')
cos_rank
# Out:
# Rubric: Космос
#      mentions                     name
# 0           8                 Эйнштейн
# 1           6                  Пифагор
# 2           5                    Эдгар
# 3           3            Стивен Хокинг
# 4           3                  Галилей
# 5           3          Артем Елмуратов
# 6           3                Эйнштейна
# 7           3                Эддингтон
# 8           2          Артур Эддингтон
# 9           2            Вальтер Бааде
# 10          2                   Кто-То
# 11          2                   Рассел
# 12          2               Филиппенко
# 13          2             Карла Сагана
# 14          2                    Штерн
# 15          2           Альберто Каппи
# 16          2              Л. Сасскинд
# 17          2            Ричард Ларсон
# 18          2                     Джой
# 19          2                   Кеплер
# 20          2                  Панчина
# 21          2                   Егоров
# 22          2            Поведенческая
# 23          2                     Торн
# 24          2             Сергей Попов
# 25          2                    Линде
# 26          2              Скиапарелли
# 27          2                   Цвикки
# 28          2                   Хаббла
# 29          2           Суперсимметрия
# ..        ...                      ...
# 238         1                   Персии
# 239         1              Эдвин Хаббл
# 240         1  Пыльская Ольга Петровна
# 241         1                Вояджеров
# 242         1               Главкосмос
# 243         1              Джефф Безос
# 244         1                  Аризоны
# 245         1            Саша Рубенчик
# 246         1         Ричард Гамильтон
# 247         1                Перельман
# 248         1                 Пуанкаре
# 249         1               Питер Лакс
# 250         1               Перегрином
# 251         1                   Грачев
# 252         1                 Фридмана
# 253         1          И. С. Шкловский
# 254         1                 Р. Дикке
# 255         1          Дэвид Вилкинсон
# 256         1        Стивена Вайнберга
# 257         1          Стивен Вайнберг
# 258         1            Дэвид Джевитт
# 259         1    Койпера Дэвид Джевитт
# 260         1                   Койпер
# 261         1          Хулио Фернандез
# 262         1                  Койпера
# 263         1              Яном Оортом
# 264         1                     Оорт
# 265         1                 Коперник
# 266         1             Юлиус Шиллер
# 267         1                  Кассини
#
# [268 rows x 2 columns]

# %%
math_rank = rank_per_rubric(ner_meta, 'Математика')
math_rank
# Out:
# Rubric: Математика
#      mentions                       name
# 0           9                Колмогорова
# 1           8                 Колмогоров
# 2           4                        Апу
# 3           3                  Перельман
# 4           3           Мариам Мирзахани
# 5           3                   Семереди
# 6           3           Сколтеха Бурнаев
# 7           3                     Римана
# 8           3                      Левин
# 9           3                       Блэк
# 10          2                       Коэн
# 11          2                      Риман
# 12          2                     Марков
# 13          2                 Перельмана
# 14          2                  Мирзахани
# 15          2              Анри Пуанкаре
# 16          2                   Демокрит
# 17          2                     Пачоли
# 18          2                      Гоббс
# 19          2                   Пуанкаре
# 20          2                  Дринфельд
# 21          2                    Холланд
# 22          2             Эндре Семереди
# 23          2           Сергея Измалкова
# 24          2                        Нэш
# 25          2                 М. Пачуски
# 26          2                         К.
# 27          2            Сколтеха Шапеев
# 28          2                    Захаров
# 29          2                   Воронцов
# ..        ...                        ...
# 199         1                       Шеня
# 200         1                Бостонского
# 201         1                      Шнорр
# 202         1             Руди Силибраси
# 203         1                 Николаевич
# 204         1                 Кто-Нибудь
# 205         1  Ефим Арсентьевич Либерман
# 206         1         Абрамович Овсеевич
# 207         1                   Овсеевич
# 208         1          Н. К. Верещагиным
# 209         1                      В. А.
# 210         1                  Ромащенко
# 211         1       Крижевский Сатскевер
# 212         1                     Хинтон
# 213         1                       Кука
# 214         1                     Левина
# 215         1                Дэвид Сирли
# 216         1                   Дафни Яо
# 217         1             Дороти Деннинг
# 218         1             Стефани Форест
# 219         1                     Бентам
# 220         1             Герберт Саймон
# 221         1                Ашенфельтер
# 222         1                     Симонс
# 223         1              Роберт Мертон
# 224         1                     Шоулза
# 225         1                     Оккама
# 226         1                    Павлова
# 227         1       Давидович Степанский
# 228         1                   Елисеева
#
# [229 rows x 2 columns]

# %%
cult_rank = rank_per_rubric(ner_meta, 'Культура')
cult_rank
# Out:
# Rubric: Культура
#      mentions                        name
# 0           7                     Толстой
# 1           7                       Саида
# 2           7                    Бельский
# 3           6                    Витрувий
# 4           6                       Ницше
# 5           5                     Тынянов
# 6           5                    Дженкинс
# 7           5                       Хайям
# 8           5                      Бахтин
# 9           5                       Хадид
# 10          4                    Булгаков
# 11          4                 Достоевский
# 12          4                      Кто-То
# 13          4                    Ганнинга
# 14          4                      Платон
# 15          4                    Малларме
# 16          3            Наталья Самутина
# 17          3                    Алексеев
# 18          3  Сергей Сергеевич Аверинцев
# 19          3                    Византия
# 20          3                Чернышевский
# 21          3                       Часто
# 22          3                      Веблен
# 23          3                     Лотмана
# 24          3                     Бахтина
# 25          3                       Данте
# 26          3                      Мольер
# 27          3                     Маклюэн
# 28          3                       Лахта
# 29          3                       Малви
# ..        ...                         ...
# 555         1                   Антонович
# 556         1             Тадеуш Рыльский
# 557         1                  Корнейчука
# 558         1          Татьяна Николаевна
# 559         1                  Петровский
# 560         1                    Коротича
# 561         1                      Хрущев
# 562         1               Петр Ефимович
# 563         1                      Суслов
# 564         1                   Рудницкий
# 565         1         Когда-То Солженицын
# 566         1                      Лотман
# 567         1       Когда-То Генрих Гейне
# 568         1                    Залыгина
# 569         1        Николай Спиридонович
# 570         1                  Платонович
# 571         1             Фаустуса Томаса
# 572         1                 Порфирьевич
# 573         1                      Микола
# 574         1                 Паустовский
# 575         1                   Щербицкий
# 576         1                        Йому
# 577         1                    Фаустуса
# 578         1                  Лермонтова
# 579         1                      Виверс
# 580         1          Николая Сетницкого
# 581         1                     Федоров
# 582         1                      Оксаны
# 583         1             Элвина Тоффлера
# 584         1             Акселем Брансом
#
# [585 rows x 2 columns]

# %%
geo_rank = rank_per_rubric(ner_meta, 'Науки о земле')
geo_rank
# Out:
# Rubric: Науки о земле
#     mentions                    name
# 0          2               Киевского
# 1          2                Святский
# 2          2                  Хадсон
# 3          2                   Майкл
# 4          2           Сергей Тархов
# 5          1                Клименко
# 6          1       Палеоклиматология
# 7          1                    Ин-Т
# 8          1              Каганского
# 9          1       Татьяны Нефедовой
# 10         1      Мераб Мамардашвили
# 11         1                 Вегенер
# 12         1               Смирнягин
# 13         1                   Куртц
# 14         1                   Оскол
# 15         1               Нефедовой
# 16         1       Стенфорд Флемминг
# 17         1                Франклин
# 18         1                   Часто
# 19         1                  Плиний
# 20         1                  Платон
# 21         1           Стива Спаркса
# 22         1               Старостин
# 23         1              Московской
# 24         1                 Даниэль
# 25         1  Неслучайно Карл Ясперс
# 26         1                 Семенов
# 27         1                 Чукотка
# 28         1               Татарстан
# 29         1              Татарстана
# 30         1               Арсеньева
# 31         1            Леопольдович
# 32         1                Бродский
# 33         1              Кордонский
# 34         1                  Чубайс
# 35         1          Николя Саркози
# 36         1            Юрий Плюснин
# 37         1           В. Селеменева
# 38         1             В. Семенова
# 39         1          Серхио Веласко
# 40         1               Селеменев
# 41         1                  Лукина
# 42         1                   Гольц
# 43         1                Трейвиша
# 44         1               Завьялова
# 45         1     Сергеевич Завалишин
# 46         1           Олег Изюмский

# %%
polit_rank = rank_per_rubric(ner_meta, 'Политология')
polit_rank
# Out:
# Rubric: Политология
#      mentions                                 name
# 0           5                                Шмитт
# 1           4                                Путин
# 2           4                                Ленин
# 3           4                             Портнова
# 4           3                                 Фуко
# 5           3                                Руссо
# 6           2                         Ходорковский
# 7           2                                Ясина
# 8           2                             Зиновьев
# 9           2                         Мичиганского
# 10          2                                Павел
# 11          2  Московского Карнеги Дмитрия Тренина
# 12          2                               Путина
# 13          2                                Жижек
# 14          2                               Ботеро
# 15          2                                Гоббс
# 16          2                             Гладырев
# 17          2                             Калугина
# 18          2                              Гельман
# 19          2                           Хантингтон
# 20          2                             Горбачев
# 21          2                             Янукович
# 22          2                          Павловского
# 23          2                              Портнов
# 24          2                              Дюверже
# 25          1                     Ольги Бессоновой
# 26          1                           Явлинского
# 27          1                       Гарри Каспаров
# 28          1                             Каспаров
# 29          1                               Ленина
# ..        ...                                  ...
# 154         1                           Джерри Хаф
# 155         1                               Роберт
# 156         1                  Николаевича Ельцина
# 157         1                            Самойлова
# 158         1                               Катона
# 159         1                       Юхана Норберга
# 160         1                              Гуандун
# 161         1                              Вольтер
# 162         1                               Людвиг
# 163         1                                Мизес
# 164         1                             Штраусом
# 165         1                            Моргентау
# 166         1                               Кто-То
# 167         1                        Пьера Валлона
# 168         1                               Шишкин
# 169         1                        Морис Дюверже
# 170         1                                Друпп
# 171         1                                Джонс
# 172         1                     Скотт Мейнверинг
# 173         1                               Томаса
# 174         1                                Кынев
# 175         1                              Любарев
# 176         1                                Обама
# 177         1                               Ельцин
# 178         1                      Анжея Валицкого
# 179         1                              Ельцина
# 180         1                              Гедройц
# 181         1                                Кушко
# 182         1                           Бессарабия
# 183         1                         Карлос Менем
#
# [184 rows x 2 columns]

# %%
psy_rank = rank_per_rubric(ner_meta, 'Психология')
psy_rank
# Out:
# Rubric: Психология
#      mentions                      name
# 0           8                 Винникотт
# 1           4                     Фрейд
# 2           3                    Маслоу
# 3           3          Татьяна Карягина
# 4           3                  Бартлетт
# 5           3            Татьяна Котова
# 6           3                 Эббингауз
# 7           2                      Карл
# 8           2                     Солоу
# 9           2                     Падун
# 10          2                     Тахир
# 11          2                   Канеман
# 12          2                    Фидлер
# 13          2              Грегори Эшби
# 14          2             Зигмунд Фрейд
# 15          2              Нейл Постман
# 16          2                     Левин
# 17          2                    Маккои
# 18          2                      Рибо
# 19          2                    Дернер
# 20          2                    Фрейда
# 21          1                 Резерфорд
# 22          1                     Тарда
# 23          1                    Сигеле
# 24          1         Урсула Штаудингер
# 25          1                    Нюттен
# 26          1           Филипп Зимбардо
# 27          1                 Вообще-То
# 28          1         Фредерика Тейлора
# 29          1        Рональда Инглхарта
# ..        ...                       ...
# 172         1  Фредерик Чарльз Бартлетт
# 173         1              Ноам Хомский
# 174         1            Герберт Саймон
# 175         1                Эббингауза
# 176         1          Герман Эббингауз
# 177         1              Майкл Познер
# 178         1                    Маккою
# 179         1                  Лафферти
# 180         1                     Греве
# 181         1                   Санделл
# 182         1                   Уланова
# 183         1                     Дэвид
# 184         1               Гай Вудрафф
# 185         1                Алан Лешли
# 186         1                     Черри
# 187         1                   Хомский
# 188         1           Аксель Клирманс
# 189         1                  Мопассан
# 190         1                   Ольвеус
# 191         1           Киберпсихология
# 192         1           Уильяма Гордона
# 193         1            Психоаналитики
# 194         1                     Огден
# 195         1                Андре Грин
# 196         1                Винникотта
# 197         1          Иоганном Хофером
# 198         1                   Ясперса
# 199         1                 Алан Хирш
# 200         1                Ульрих Орт
# 201         1              Орели Буррен
#
# [202 rows x 2 columns]

# %%
soc_rank = rank_per_rubric(ner_meta, 'Социология')
soc_rank
# Out:
# Rubric: Социология
#      mentions                   name
# 0          15                Гоффман
# 1          10                 Кто-То
# 2          10                  Латур
# 3           8                 Вулгар
# 4           7                    Шюц
# 5           7                 Колхас
# 6           6                Федотов
# 7           6                 Аузана
# 8           6                  Аузан
# 9           6                  Путин
# 10          6               Медведев
# 11          6                 Скотта
# 12          5             Павловский
# 13          5               Дюркгейм
# 14          5                Поланьи
# 15          4           Ходорковский
# 16          4                  Часто
# 17          4                  Хайек
# 18          4                  Маркс
# 19          4                  Скотт
# 20          4             Ключевский
# 21          4                  Шмитт
# 22          4                Зиммель
# 23          4             Опанасенко
# 24          3          Крыштановский
# 25          3               Довженко
# 26          3                   Сота
# 27          3                Харшани
# 28          3            Дуглас Норт
# 29          3               Олегович
# ..        ...                    ...
# 618         1               Конфуций
# 619         1           Бенно Верлен
# 620         1               Лейбницу
# 621         1   Вахштайна Пересборка
# 622         1               Шадриной
# 623         1           Питер Стернс
# 624         1               Маргарет
# 625         1         Филиппа Арьеса
# 626         1                  Пшеры
# 627         1      Сэмюэл Хантингтон
# 628         1                Оккупай
# 629         1  Интернет-Исследования
# 630         1                 Серова
# 631         1                Кубанин
# 632         1             Заславской
# 633         1      Никита Покровский
# 634         1         Сергей Толстов
# 635         1                Уильяма
# 636         1                   Вибе
# 637         1                 Латура
# 638         1                 Элиаса
# 639         1         Герд Хаберманн
# 640         1               Караджич
# 641         1                Архимед
# 642         1                 Ульрих
# 643         1              Шляпентох
# 644         1                  Шанин
# 645         1               Матвеева
# 646         1               Кузнецов
# 647         1                  Кейнс
#
# [648 rows x 2 columns]

# %%
tech_rank = rank_per_rubric(ner_meta, 'Технологии')
tech_rank
# Out:
# Rubric: Технологии
#      mentions                        name
# 0          11                      Видлар
# 1           5                      Морита
# 2           4                      Кто-То
# 3           4                  Куренниеми
# 4           4                      Патрик
# 5           4                     Шушурин
# 6           4                    Мацусита
# 7           3               Роберт Видлар
# 8           3                       Бошлу
# 9           3                      Меуччи
# 10          3                       Грина
# 11          3                  Зеннхайзер
# 12          2                        Акио
# 13          2                      Эдисон
# 14          2                     Антонио
# 15          2                 Дэнос Газис
# 16          2                        Грин
# 17          2                  Николелиса
# 18          2                         Лео
# 19          2                   Кузьминым
# 20          2                    Кузьмина
# 21          2                Шелейховский
# 22          1              С. К. Далсгард
# 23          1            Джеффа Моррисона
# 24          1                 Ньюенхайзен
# 25          1                 Витор Санта
# 26          1                        Мэтт
# 27          1            Анджела Букингем
# 28          1             Томас Метцингер
# 29          1                   Стэнфорда
# ..        ...                         ...
# 227         1                        Стив
# 228         1                  Макдоналдс
# 229         1                 Стрельников
# 230         1                       Вучик
# 231         1        Христофорович Озеров
# 232         1                     Дубелир
# 233         1  Абрам Хаимович Зильберталь
# 234         1             Юрий Михайлович
# 235         1                        Руси
# 236         1                    Михайлов
# 237         1             Татьяна Толстая
# 238         1                    Чиркунов
# 239         1                Адольфа Шайе
# 240         1                    Данидине
# 241         1       Корнелиусом Дреббелем
# 242         1              Алана Тьюринга
# 243         1                    Дуданова
# 244         1                  Уилл Скотт
# 245         1                       Фурье
# 246         1                     Неплохо
# 247         1                       Аалто
# 248         1            Сиддха Пимпуткар
# 249         1                        Хаус
# 250         1              Дэниел Ворледж
# 251         1                     Кэрролл
# 252         1                Саймон Мдума
# 253         1            Джастин Брейшерз
# 254         1                    Синклера
# 255         1             Томаса Мальтуса
# 256         1                 Рэй Хилборн
#
# [257 rows x 2 columns]

# %%
ph_rank = rank_per_rubric(ner_meta, 'Физика')
ph_rank
# Out:
# Rubric: Физика
#      mentions                     name
# 0          22                   Декарт
# 1          12                 Эйнштейн
# 2          10                 Максвелл
# 3           6                    Дирак
# 4           5                    Паули
# 5           4                   Хиггса
# 6           4                Резерфорд
# 7           4                Эйнштейна
# 8           4                  Фейнман
# 9           4                   Мурзин
# 10          4                  Декарта
# 11          4                    Часто
# 12          3                   Ландау
# 13          3  Сколтеха Ильдар Габитов
# 14          3                  Беднорц
# 15          3                    Питер
# 16          3               Карабутова
# 17          3                  Термена
# 18          3                Максвелла
# 19          3                  Беекман
# 20          3                    Цвейг
# 21          3                   Дирака
# 22          3                   Термен
# 23          2         Ричарда Фейнмана
# 24          2          Фрэнка Вильчека
# 25          2                Зельдович
# 26          2         Альберт Эйнштейн
# 27          2                    Линде
# 28          2                  Козлова
# 29          2         Майклом Фарадеем
# ..        ...                      ...
# 359         1                   Платон
# 360         1                    Койре
# 361         1                  Фукидид
# 362         1                 Порфирий
# 363         1                 Августин
# 364         1                  Евклида
# 365         1                  Гипатия
# 366         1                  Филопон
# 367         1                 Сколтеха
# 368         1                    Фурье
# 369         1           Райнеру Вайссу
# 370         1                Борексино
# 371         1                   Глэшоу
# 372         1            Исаму Акасаки
# 373         1                     Унру
# 374         1            Ричард Мюллер
# 375         1          Джозефом Хафеле
# 376         1        Ричардом Китингом
# 377         1                   Хафеле
# 378         1                   Китинг
# 379         1      Сколтеха Перебейнос
# 380         1          Армена Сергеева
# 381         1                   Олсона
# 382         1                Верховцев
# 383         1                    Лютов
# 384         1                  Дорохов
# 385         1                Ломоносов
# 386         1               Польгрином
# 387         1                Шредингер
# 388         1                      Янг
#
# [389 rows x 2 columns]

# %%
phis_rank = rank_per_rubric(ner_meta, 'Физиология человека')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-a90e486bb27b> in <module>()
# ----> 1 phis_rank = rank_per_rubric(ner_meta, 'Физиология человека')
#
# NameError: name 'rank_per_rubric' is not defined

# %%
phil_rank = rank_per_rubric(ner_meta, 'Философия')
phil_rank
# Out:
# Rubric: Философия
#      mentions                  name
# 0          10                 Ницше
# 1           9            Аристотель
# 2           7                Платон
# 3           5               Мэдисон
# 4           5                 Лосев
# 5           4                Сократ
# 6           4            Макиавелли
# 7           4              Булгаков
# 8           3                Гегеля
# 9           3                Арендт
# 10          3                Штраус
# 11          3                 Оккам
# 12          3    Никколо Макиавелли
# 13          3           Витгенштейн
# 14          3                 Шмитт
# 15          3                Гегель
# 16          3                Батлер
# 17          3                Хомски
# 18          3           Достоевский
# 19          3               Нумений
# 20          2               Шеллинг
# 21          2              Августин
# 22          2              Соловьев
# 23          2                Беркли
# 24          2               Платона
# 25          2           Мишеля Фуко
# 26          2                Лаклау
# 27          2                 Маркс
# 28          2           Лео Штрауса
# 29          2               Николай
# ..        ...                   ...
# 114         1               Филлиды
# 115         1   Эразм Роттердамский
# 116         1   Философ-Эпистемолог
# 117         1         Этьен Балибар
# 118         1         Принстонского
# 119         1    Бенжамена Констана
# 120         1                 Исайя
# 121         1       Чино Ринунччини
# 122         1         Стюарта Милля
# 123         1        Артемия Магуна
# 124         1              Жарковым
# 125         1              Урбинати
# 126         1      Сергия Булгакова
# 127         1                 София
# 128         1               Булдяев
# 129         1              Бергаков
# 130         1           Пятигорский
# 131         1                Нового
# 132         1              Упанишад
# 133         1      Весой Ойттиненом
# 134         1       Николай Бердяев
# 135         1            Кропоткине
# 136         1          Ричард Рорти
# 137         1                 Рорти
# 138         1       Чандран Кукатас
# 139         1              Соломона
# 140         1           Экклесиаста
# 141         1  Ван Ренсселер Поттер
# 142         1            Б. Г. Юдин
# 143         1    Скарлетт Йоханссон
#
# [144 rows x 2 columns]

# %%
fut_rank = rank_per_rubric(ner_meta, 'Футурология')
fut_rank
# Out:
# Rubric: Футурология
#     mentions                      name
# 0          2                  Макклюен
# 1          2           Павел Клушанцев
# 2          2                       Бен
# 3          2                      Тони
# 4          2                     Иниго
# 5          2                     Кларк
# 6          2                     Джобс
# 7          2                       Мур
# 8          1          Маршалл Макклюен
# 9          1                    Дурова
# 10         1                     Пропп
# 11         1           Джозеф Кэмпбелл
# 12         1                 Клушанцев
# 13         1                    Скотак
# 14         1                     Лукас
# 15         1                     Часто
# 16         1                  Уильямса
# 17         1                 Голливуда
# 18         1                    Кудрин
# 19         1             Станислав Лем
# 20         1      Джералдом Эдельманом
# 21         1             Стивен Хокинг
# 22         1                   Хокинга
# 23         1                Амал Дорай
# 24         1       Вконтакте Вконтакте
# 25         1           Кристофер Прист
# 26         1                Чайковский
# 27         1                     Свифт
# 28         1             Лютера Трента
# 29         1                     Ральф
# 30         1            Эдвард Беллами
# 31         1             Мартин Кайдин
# 32         1             Роберт Невилл
# 33         1          Кормака Маккарти
# 34         1  Илая Герой-Одиночка Илай
# 35         1              Айзек Азимов
# 36         1            Майкл Анисимов
# 37         1                  Эрика К.
# 38         1                   Севейдж
# 39         1                     Энджи
# 40         1            Урсула Ле Гуин
# 41         1               Майкл Фабер
# 42         1                     Гарри
# 43         1                    Кто-То
# 44         1                 Энди Вейр
# 45         1                      Шейн

# %%
chem_rank = rank_per_rubric(ner_meta, 'Химия')
chem_rank
# Out:
# Rubric: Химия
#     mentions                         name
# 0          4                          Цуи
# 1          2                        Паули
# 2          2                        Леман
# 3          2                Иоганн Кеплер
# 4          2                       Кеплер
# 5          2       Сколтеха Фардад Азарми
# 6          2                       Эдисон
# 7          2                        Фокин
# 8          1                   Завойского
# 9          1                   Исаак Раби
# 10         1               Ричарда Эрнста
# 11         1                     Рейницер
# 12         1                    Фредерикс
# 13         1                     Колорадо
# 14         1           Сонина Степановича
# 15         1            Петровича Шибаева
# 16         1                     Фурсенко
# 17         1                       Дженкс
# 18         1            Сколтеха Слесарев
# 19         1               Роджер Пенроуз
# 20         1              Дэном Шехтманом
# 21         1                      Шехтман
# 22         1                      Блатова
# 23         1  Мартин Карплюс Майкл Левитт
# 24         1                   Ари Уоршел
# 25         1               Мартин Карплус
# 26         1              Карплуса Левитт
# 27         1                       Уоршел
# 28         1                       Боэрле
# 29         1                    Мельников
# ..       ...                          ...
# 70         1                 Гуйлиньского
# 71         1               Николай Стенон
# 72         1                         Лауэ
# 73         1                 Ричард Клегг
# 74         1                   Ломоносова
# 75         1           Микелле Парринелло
# 76         1                    Англичане
# 77         1                        Гроув
# 78         1                       Бейкон
# 79         1                  Дэвид Прайс
# 80         1                     Леенсона
# 81         1                       Кольбе
# 82         1         Карл Теодор Либерман
# 83         1          Ричарда Дронсковски
# 84         1                  Параллельно
# 85         1               П. С. Федотову
# 86         1                   Гиддингсом
# 87         1                Льюис Кэрролл
# 88         1               Ричарда Клегга
# 89         1                       Марвин
# 90         1                     Бутлеров
# 91         1                        Прайс
# 92         1                Лейф Эрикссон
# 93         1                  Штефан Хелл
# 94         1              Уильяма Мернера
# 95         1                         Чена
# 96         1                  Эрик Бетциг
# 97         1                       Тропша
# 98         1                        Исаев
# 99         1                     Годунова
#
# [100 rows x 2 columns]

# %%
econ_rank = rank_per_rubric(ner_meta, 'Экономика')
econ_rank
# Out:
# Rubric: Экономика
#      mentions                     name
# 0           5                     Смит
# 1           5                    Кейнс
# 2           4            Сергей Гуриев
# 3           4                   Кейнса
# 4           3             Рональд Коуз
# 5           3             Бен Бернанке
# 6           3                     Харт
# 7           3                  Белянин
# 8           3              Гэри Беккер
# 9           3                  Кругман
# 10          3         Кайрат Нематович
# 11          3                   Ричард
# 12          2                   Дэвида
# 13          2              Полтеровича
# 14          2                Вальдмана
# 15          2                      Жан
# 16          2              Нобелевскои
# 17          2                    Часто
# 18          2  Сколтеха Игорь Ужинский
# 19          2          Мейнарда Кейнса
# 20          2                   Кто-То
# 21          2           Милтон Фридман
# 22          2                  Фридман
# 23          2                  Канеман
# 24          2                  Тверски
# 25          2                 Стиглица
# 26          2                 Британия
# 27          2                 Госбанка
# 28          2                  Штиглиц
# 29          2                 Рузвельт
# ..        ...                      ...
# 234         1                    Паппэ
# 235         1            Алан Гринспен
# 236         1                   Никсон
# 237         1                  Бродель
# 238         1                    Питер
# 239         1                    Токио
# 240         1         Мануэль Кастельс
# 241         1                   Энтони
# 242         1                  Вирильо
# 243         1            Ричард Лэйард
# 244         1                   Балтии
# 245         1                Декаплинг
# 246         1                 Куиггина
# 247         1                    Смита
# 248         1       Сэнфорду Гроссману
# 249         1         Джозефу Стиглицу
# 250         1       Джеймсу Шуровьески
# 251         1                  Вальрас
# 252         1                  Стиглиц
# 253         1                    Тьебу
# 254         1              Наоми Кляйн
# 255         1                Григорьев
# 256         1                    Дитон
# 257         1            Чарльз Дарвин
# 258         1           Герберт Кэссон
# 259         1           Томасу Эдисону
# 260         1                Зиттрейна
# 261         1           Йозеф Шумпетер
# 262         1                 Шумпетер
# 263         1                     Вейл
#
# [264 rows x 2 columns]

# %%
ling_rank = rank_per_rubric(ner_meta, 'Язык')
ling_rank
# Out:
# Rubric: Язык
#      mentions              name
# 0           8       Витгенштейн
# 1           4        Пешковский
# 2           4           Плунгян
# 3           3     Стивен Пинкер
# 4           3            Кто-То
# 5           3         Сыма Цянь
# 6           3           Хомский
# 7           3            Бейкер
# 8           3            Платон
# 9           3          Бикертон
# 10          2  Арнольд Чикобава
# 11          2          Зализняк
# 12          2            Гивона
# 13          2      Ноам Хомский
# 14          2          Плунгяна
# 15          2       Ноам Хомски
# 16          2         Новгороде
# 17          2   М. Л. Бутовская
# 18          2    Л. А. Файнберг
# 19          2            Дарвин
# 20          2    Нина Сумбатова
# 21          2         Иммануила
# 22          2           Бейкера
# 23          2      Мамардашвили
# 24          2       Расмус Раск
# 25          2          Муравьев
# 26          2         По-Русски
# 27          2            Толкин
# 28          2               Гая
# 29          2           Толстой
# ..        ...               ...
# 252         1        Алан Ченки
# 253         1    Николай Конрад
# 254         1         Зализняку
# 255         1            Питере
# 256         1   Астрид Линдгрен
# 257         1       Сары Шарплз
# 258         1      Тодд Лэндмен
# 259         1         Протасова
# 260         1    Дитрих Тидеман
# 261         1   Чарльзу Дарвину
# 262         1        Якоб Гримм
# 263         1              Муму
# 264         1    Е. Г. Эткиндом
# 265         1             Павел
# 266         1          Одинцова
# 267         1            Фауста
# 268         1          Базарова
# 269         1     Эпилептоидами
# 270         1          Загоскин
# 271         1           Лукерья
# 272         1         Сергеевич
# 273         1      Паустовского
# 274         1      Николай Марр
# 275         1              Марр
# 276         1          Обериуты
# 277         1           Велимир
# 278         1             Гройс
# 279         1             Маркс
# 280         1            Сталин
# 281         1           Сталина
#
# [282 rows x 2 columns]

# %% [markdown]
# ## Parse full corpora

# %%
def parse_xml(xml_output):
    xml = bs.BeautifulSoup(xml_output, 'lxml')
    names = xml.find_all('name')
    pattern = re.compile(r'val="([А-ЯЁ]+)">')
    names_ext = []
    for name in names:
        name = name.get('val')
        names_ext.append(name)
    names_ext = [name.title() for name in names_ext]
    #names_sep = divide_names(names_ext)
    #return names_sep
    return names_ext

# %%
names = parse_xml(output)
len(names)
# Out:
# 729

# %% [markdown]
# ## Delete common words and geoterms

# %%
import pymorphy2 
morph = pymorphy2.MorphAnalyzer()
from flashtext import KeywordProcessor
from tqdm import tqdm_notebook
import pandas as pd

# %% [markdown]
# ### Comile a list of common words in the beginning of the sentence

# %%
meta_table = pd.read_csv('/home/alapidus/NIS/articles_with_meta.tsv', sep='\t')

# %%
from nltk.tokenize.punkt import PunktSentenceTokenizer

# %%
tokenizer = PunktSentenceTokenizer()

# %%
def preprocess(text):
    text = ' '.join(re.findall(r'[А-ЯЁа-яё\-\.\d]+', text))
    return text

# %%
def find_first_words(texts):
    words = []
    for text in tqdm(texts):
        text = preprocess(text)
        sentences = tokenizer.tokenize(text)
        first_words = [sentence.split()[0] for sentence in sentences]
        first_words = [w.lower() for w in first_words]
        words.extend(first_words)
    return list(set(words))

# %%
first_words = find_first_words(meta_table.text)
# Out:
# 100%|██████████| 30628/30628 [01:48<00:00, 283.35it/s]

# %%
def compile_lemmas_list(input_path):
    lemmas_list = []
    for root, dirs, files in os.walk(input_path):
        for file_name in files:
            file_path = input_path + file_name
            lemmas = slurp(file_path)
            lemmas = re.findall(r'[а-яё]+', lemmas)
            lemmas_list.extend(lemmas)
    lemmas_list = list(set(lemmas_list))
    return lemmas_list

# %%
common = '/home/nst/data/api_nis/ner_module/other_dir/slovnik/'
common_words = compile_lemmas_list(common)

# %%
lemmas_processor = KeywordProcessor()
lemmas_processor.add_keywords_from_list(common_words)

# %%
cities = pd.read_csv('/home/nst/data/api_nis/ner_module/other_dir/cities.csv', sep='\t', 
                     names=['geoloc', 'mentions'])
countries = pd.read_csv('/home/nst/data/api_nis/ner_module/other_dir/countries.csv', sep='\t', 
                    names = ['geoloc', 'mentions'])
geo_general = pd.read_csv('/home/nst/data/api_nis/ner_module/other_dir/geo_names.tsv', sep='\t',
                         names= ['geoloc'])

# %%
geo = pd.concat([cities, countries, geo_general])
geo = geo.drop_duplicates(keep='first')
# Out:
# /home/nst/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   """Entry point for launching an IPython kernel.

# %%
geo = geo.geoloc

# %%
geo = list(geo)

# %%
geo = [loc.lower() for loc in geo]

# %%
lemmas_geo = KeywordProcessor()
lemmas_geo.add_keywords_from_list(geo)

# %%
def delete_common_words(names:list):
    potential_names = []
    
    for name in names:
        true_name = []
        name = name.split()
        for n in name:
            n = n.lower()
            lemma = morph.parse(n)[0].normal_form
            if not lemmas_processor.extract_keywords(lemma) == [lemma]:
                #print('not in common:', lemma)
                true_name.append(n.title())
        final_name = ' '.join(true_name)
        if final_name != '':
            potential_names.append(final_name)
    #print('Deleted common words, current size:', len(potential_names))
    return potential_names

# %%
len(names)
# Out:
# 9

# %%
commons_deleted = delete_common_words(names)

# %%
len(commons_deleted)
# Out:
# 470

# %%
def delete_geo_terms(names:list):
    potential_names = []
    
    for name in names:
        true_name = []
        name = name.split()
        for n in name:
            n = n.lower()
            lemma = morph.parse(n)[0].normal_form
            if not lemmas_geo.extract_keywords(lemma) == [lemma]:
                #print('not in common:', lemma)
                true_name.append(n.title())
        final_name = ' '.join(true_name)
        if final_name != '':
            potential_names.append(final_name)
    #print('Deleted geo terms, current size:', len(potential_names))
    return potential_names

# %%
geo_delete = delete_geo_terms(commons_deleted)

# %%
len(geo_delete)
# Out:
# 456

# %%
clean_names=geo_delete

# %%
true = names_list

# %%
pred = []
for name in clean_names:
    if name in true:
        pred.append(name)
accuracy = len(pred)/len(true)
print('Accuracy:', accuracy)
# Out:
# Accuracy: 0.4798061389337641

# %% [markdown]
# ## Пройдемся по текстам и списку из корпуса

# %%
corpora_names = [name.strip() for name in corpora_names]

# %%
# %%time
for text in tqdm_notebook(preprocessed):
    for n in corpora_names:
        if n in text:
            clean_names.append(n)
# Out:
# HBox(children=(IntProgress(value=0, max=175), HTML(value='')))
# CPU times: user 23.9 s, sys: 73.7 ms, total: 24 s
# Wall time: 24.4 s

# %%
from collections import Counter

# %%
names_dict = dict(Counter(geo_delete))
names_sorted = sorted(names_dict.items(), key = lambda x:x[1], reverse=True)

# %%
names_sorted.remove(('Московского', 7))

# %%
names = [name[0] for name in names_sorted]
mentions = [name[1] for name in names_sorted]
names_sorted_df = pd.DataFrame({'name':names,
                                'mentions': mentions})

# %%
names_sorted_df.to_csv('/home/alapidus/NIS/ner_data/general_ranking.tsv', sep='\t')
